# %%
# !pip install "psycopg[binary]"
# !pip install sqlalchemy
# Out:
# Collecting psycopg[binary]
#   Downloading psycopg-3.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: typing-extensions>=4.6 in c:\healthcare\.venv\lib\site-packages (from psycopg[binary]) (4.16.0)
# Requirement already satisfied: tzdata in c:\healthcare\.venv\lib\site-packages (from psycopg[binary]) (2026.3)
# Collecting psycopg-binary==3.3.4 (from psycopg[binary])
#   Downloading psycopg_binary-3.3.4-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Downloading psycopg_binary-3.3.4-cp311-cp311-win_amd64.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.6 MB 1.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.1/3.6 MB 1.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.4/3.6 MB 3.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.6 MB 6.7 MB/s eta 0:00:01
#    --------------------------- ------------ 2.5/3.6 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.6 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.6/3.6 MB 13.4 MB/s eta 0:00:00
# Downloading psycopg-3.3.4-py3-none-any.whl (213 kB)
#    ---------------------------------------- 0.0/213.0 kB ? eta -:--:--
#    --------------------------------------- 213.0/213.0 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: psycopg-binary, psycopg
# Successfully installed psycopg-3.3.4 psycopg-binary-3.3.4
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sqlalchemy in c:\healthcare\.venv\lib\site-packages (2.0.51)
# Requirement already satisfied: greenlet>=1 in c:\healthcare\.venv\lib\site-packages (from sqlalchemy) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\healthcare\.venv\lib\site-packages (from sqlalchemy) (4.16.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# LangSmith에서 Tracing을 하고싶다면 키 변경후 아래의 주석 해제
# 반드시 LangChain import 전에 설정
# import os
# os.environ["LANGSMITH_TRACING"] = "true"
# os.environ["LANGSMITH_API_KEY"] = "LangSmith에서 발급받은 키"
# os.environ["LANGSMITH_PROJECT"] = "healthcare"

# ============================================================
# 설정 함수
# ============================================================

def get_config() -> dict:
    """
    RAG 파이프라인 전체에서 사용하는 설정값을 반환합니다.
    환경변수나 외부 설정 파일로 교체하기 쉽도록 함수로 분리합니다.
    DB접속정보는 강의환경정보 시트 참조 : https://docs.google.com/spreadsheets/d/145GlLN4vV90KBLFj8g_xdWbVK-2lfE2qGD8u9keZJk8/edit?usp=sharing
    """
    return {
        "db_host":        "classdb.iranglab.com",
        "db_port":        5432,
        "db_name":        "db15",
        "db_user":        "user15",
        "db_password":    "user1599!",
        "ollama_base_url": "http://localhost:11434",
        "llm_model":      "qwen2.5:3b",
        "embed_model":    "bge-m3",
        "embedding_dim":  1024,
        "collection_name": "healthcare_docs",
        "chunk_size":     800,
        "chunk_overlap":  120,
    }

# ============================================================
# DB 연결 함수
# ============================================================
from sqlalchemy import create_engine, text


def get_db_engine(config: dict):
    """
    설정에서 SQLAlchemy 엔진을 생성하고 연결을 검증한 뒤 반환합니다.
    연결 실패 시 예외를 발생시킵니다.
    """
    url = (
        f"postgresql+psycopg://{config['db_user']}:{config['db_password']}"
        f"@{config['db_host']}:{config['db_port']}/{config['db_name']}"
    )
    engine = create_engine(url, pool_pre_ping=True, pool_recycle=1800)
    with engine.connect() as conn:
        conn.execute(text("SELECT 1"))
    print(f"PostgreSQL 연결 성공: {config['db_host']}:{config['db_port']}/{config['db_name']}")
    return engine

#DB 초기화
config = get_config()
engine = get_db_engine(config)
# Out:
# PostgreSQL 연결 성공: classdb.iranglab.com:5432/db15

# %%
# !pip install langchain_pymupdf4llm
# Out:
# Collecting langchain_pymupdf4llm
#   Downloading langchain_pymupdf4llm-1.28.0-py3-none-any.whl.metadata (45 kB)
#      ---------------------------------------- 0.0/45.5 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/45.5 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 45.5/45.5 kB 452.3 kB/s eta 0:00:00
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\healthcare\.venv\lib\site-packages (from langchain_pymupdf4llm) (1.4.9)
# Collecting pymupdf4llm==1.28.0 (from langchain_pymupdf4llm)
#   Downloading pymupdf4llm-1.28.0-py3-none-any.whl.metadata (20 kB)
# Collecting pymupdf==1.28.0 (from pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Downloading pymupdf-1.28.0-cp310-abi3-win_amd64.whl.metadata (26 kB)
# Collecting pymupdf_layout==1.28.0 (from pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Downloading pymupdf_layout-1.28.0-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting tabulate (from pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.8 kB ? eta -:--:--
#      ---------------------------------------- 40.8/40.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in c:\healthcare\.venv\lib\site-packages (from pymupdf_layout==1.28.0->pymupdf4llm==1.28.0->langchain_pymupdf4llm) (6.0.3)
# Collecting numpy (from pymupdf_layout==1.28.0->pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting onnxruntime (from pymupdf_layout==1.28.0->pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Downloading onnxruntime-1.27.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting networkx (from pymupdf_layout==1.28.0->pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\healthcare\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\healthcare\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\healthcare\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\healthcare\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.4.2)
# Requirement already satisfied: idna>=2.8 in c:\healthcare\.venv\lib\site-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (3.18)
# Requirement already satisfied: certifi in c:\healthcare\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\healthcare\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\healthcare\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\healthcare\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\healthcare\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_pymupdf4llm) (2.7.0)
# Collecting flatbuffers (from onnxruntime->pymupdf_layout==1.28.0->pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting protobuf>=4.25.8 (from onnxruntime->pymupdf_layout==1.28.0->pymupdf4llm==1.28.0->langchain_pymupdf4llm)
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Downloading langchain_pymupdf4llm-1.28.0-py3-none-any.whl (33 kB)
# Downloading pymupdf4llm-1.28.0-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.7 kB ? eta -:--:--
#    ---------------------------------------- 164.7/164.7 kB 9.7 MB/s eta 0:00:00
# Downloading pymupdf-1.28.0-cp310-abi3-win_amd64.whl (19.8 MB)
#    ---------------------------------------- 0.0/19.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/19.8 MB 27.5 MB/s eta 0:00:01
#    --- ------------------------------------ 1.8/19.8 MB 22.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.9/19.8 MB 20.8 MB/s eta 0:00:01
#    -------- ------------------------------- 4.2/19.8 MB 24.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 5.1/19.8 MB 23.1 MB/s eta 0:00:01
#    ------------ --------------------------- 6.0/19.8 MB 22.6 MB/s eta 0:00:01
#    -------------- ------------------------- 7.0/19.8 MB 22.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 8.2/19.8 MB 22.7 MB/s eta 0:00:01
#    ------------------ --------------------- 9.4/19.8 MB 24.0 MB/s eta 0:00:01
#    --------------------- ------------------ 10.7/19.8 MB 23.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 11.3/19.8 MB 23.4 MB/s eta 0:00:01
#    ------------------------ --------------- 12.2/19.8 MB 23.4 MB/s eta 0:00:01
#    ------------------------- -------------- 12.8/19.8 MB 23.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 14.6/19.8 MB 24.2 MB/s eta 0:00:01
#    --------------------------------- ------ 16.4/19.8 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------ --- 17.9/19.8 MB 27.3 MB/s eta 0:00:01
#    -------------------------------------- - 19.2/19.8 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  19.8/19.8 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 19.8/19.8 MB 24.3 MB/s eta 0:00:00
# Downloading pymupdf_layout-1.28.0-cp310-abi3-win_amd64.whl (41.6 MB)
#    ---------------------------------------- 0.0/41.6 MB ? eta -:--:--
#    - -------------------------------------- 1.3/41.6 MB 27.5 MB/s eta 0:00:02
#    -- ------------------------------------- 2.9/41.6 MB 30.6 MB/s eta 0:00:02
#    --- ------------------------------------ 4.1/41.6 MB 29.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.2/41.6 MB 27.8 MB/s eta 0:00:02
#    ------ --------------------------------- 6.6/41.6 MB 29.9 MB/s eta 0:00:02
#    ------- -------------------------------- 7.7/41.6 MB 28.8 MB/s eta 0:00:02
#    -------- ------------------------------- 9.1/41.6 MB 29.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.5/41.6 MB 32.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 12.3/41.6 MB 31.2 MB/s eta 0:00:01
#    ------------- -------------------------- 13.9/41.6 MB 32.7 MB/s eta 0:00:01
#    -------------- ------------------------- 15.4/41.6 MB 34.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 17.0/41.6 MB 32.8 MB/s eta 0:00:01
#    ------------------ --------------------- 18.7/41.6 MB 34.4 MB/s eta 0:00:01
#    ------------------- -------------------- 19.9/41.6 MB 32.8 MB/s eta 0:00:01
#    ------------------- -------------------- 19.9/41.6 MB 32.8 MB/s eta 0:00:01
#    ------------------- -------------------- 20.4/41.6 MB 27.3 MB/s eta 0:00:01
#    -------------------- ------------------- 21.7/41.6 MB 26.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 23.3/41.6 MB 27.3 MB/s eta 0:00:01
#    ------------------------ --------------- 25.6/41.6 MB 28.5 MB/s eta 0:00:01
#    -------------------------- ------------- 27.7/41.6 MB 29.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.4/41.6 MB 31.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 30.9/41.6 MB 38.6 MB/s eta 0:00:01
#    ------------------------------- -------- 32.6/41.6 MB 40.9 MB/s eta 0:00:01
#    --------------------------------- ------ 34.3/41.6 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 36.3/41.6 MB 38.6 MB/s eta 0:00:01
#    ------------------------------------ --- 37.4/41.6 MB 36.3 MB/s eta 0:00:01
#    ------------------------------------- -- 39.2/41.6 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------------  40.7/41.6 MB 34.6 MB/s eta 0:00:01
#    ---------------------------------------  41.6/41.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  41.6/41.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 41.6/41.6 MB 27.3 MB/s eta 0:00:00
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# Downloading onnxruntime-1.27.0-cp311-cp311-win_amd64.whl (13.4 MB)
#    ---------------------------------------- 0.0/13.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.4 MB 19.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.9/13.4 MB 31.6 MB/s eta 0:00:01
#    ------------ --------------------------- 4.1/13.4 MB 32.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.8/13.4 MB 31.2 MB/s eta 0:00:01
#    --------------------- ------------------ 7.3/13.4 MB 31.2 MB/s eta 0:00:01
#    -------------------------- ------------- 8.9/13.4 MB 31.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.6/13.4 MB 38.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.0/13.4 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------  13.4/13.4 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 13.4/13.4 MB 29.7 MB/s eta 0:00:00
# Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
#    ---------------------------------------- 0.0/440.0 kB ? eta -:--:--
#    --------------------------------------- 440.0/440.0 kB 28.7 MB/s eta 0:00:00
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Installing collected packages: flatbuffers, tabulate, pymupdf, protobuf, numpy, networkx, onnxruntime, pymupdf_layout, pymupdf4llm, langchain_pymupdf4llm
# Successfully installed flatbuffers-25.12.19 langchain_pymupdf4llm-1.28.0 networkx-3.6.1 numpy-2.4.6 onnxruntime-1.27.0 protobuf-7.35.1 pymupdf-1.28.0 pymupdf4llm-1.28.0 pymupdf_layout-1.28.0 tabulate-0.10.0
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ============================================================
# PDF 로드 및 텍스트 정제 함수
# ============================================================
import os
import re
from pathlib import Path
from langchain_pymupdf4llm import PyMuPDF4LLMLoader


# ============================================================
# PDF 추출 텍스트 정제
# ============================================================
def _clean_text(text: str) -> str:
    text = re.sub(r"(\w)-\s*\n\s*(\w)", r"\1\2", text)
    text = re.sub(r"\n+", " ", text)
    text = re.sub(r"\s+", " ", text)
    return text.strip()


# ============================================================
# 파일명에서 member_id, member_name 추출
# ============================================================
def extract_member_info_from_filename(pdf_path: str) -> dict:
    """
    파일명 형식:
        id__member_id__이름.pdf
    예:
        id__user_002__이서연.pdf
    반환:
        {
            "member_id": "user_002",
            "member_name": "이서연"
        }
    """

    filename = Path(pdf_path).name
    stem = Path(pdf_path).stem

    # id__ 로 시작하지 않으면 회원 문서가 아니라고 판단
    if not stem.startswith("id__"):
        return {}

    parts = stem.split("__")

    if len(parts) != 3:
        raise ValueError(
            f"파일명 형식 오류: {filename}\n"
            "형식은 id__member_id__이름.pdf 이어야 합니다."
        )

    member_id = parts[1].strip()
    member_name = parts[2].strip()

    if not member_id or not member_name:
        raise ValueError(
            f"member_id 또는 이름을 추출할 수 없습니다: {filename}"
        )

    return {
        "member_id": member_id,
        "member_name": member_name,
    }


# ============================================================
# PDF 1개 로드
# ============================================================
def load_pdf(pdf_path: str) -> list:
    """PDF를 로드하고 텍스트를 정제하여 Document 목록으로 반환합니다."""

    if not os.path.exists(pdf_path):
        raise FileNotFoundError(f"PDF 파일이 없습니다: {pdf_path}")

    # 파일명에서 회원 정보 추출
    member_info = extract_member_info_from_filename(pdf_path)

    docs = PyMuPDF4LLMLoader(str(pdf_path)).load()

    for doc in docs:
        # 텍스트 정제
        doc.page_content = _clean_text(doc.page_content)

        # ----------------------------------------------------
        # 기본 metadata 추가
        # ----------------------------------------------------
        doc.metadata["source_file"] = os.path.basename(pdf_path)
        doc.metadata["source_path"] = str(pdf_path)
        

        # ----------------------------------------------------
        # 회원 PDF인 경우 metadata에 회원 정보 추가
        # ----------------------------------------------------
        if member_info:
            doc.metadata["member_id"] = member_info["member_id"]
            doc.metadata["member_name"] = member_info["member_name"]
            doc.metadata["source_type"] = "member_health_document"
        else:
            doc.metadata["member_id"] = None
            doc.metadata["member_name"] = None
            doc.metadata["source_type"] = "common_reference_document"

    print(f"PDF 로드 및 클린징 완료: {pdf_path} ({len(docs)}페이지)")

    if member_info:
        print(
            f"metadata 추가 완료: "
            f"member_id={member_info['member_id']}, "
            f"member_name={member_info['member_name']}"
        )
    else:
        print("metadata 추가 완료: 공통 참고문서")

    return docs


# ============================================================
# 폴더 아래의 모든 PDF 로드
# ============================================================
def load_pdfs_from_folder(folder_path: str, recursive: bool = False) -> list:
    """폴더 아래의 모든 PDF를 로드합니다."""

    folder = Path(folder_path)

    if not folder.exists():
        raise FileNotFoundError(f"폴더가 없습니다: {folder_path}")

    if not folder.is_dir():
        raise NotADirectoryError(f"폴더 경로가 아닙니다: {folder_path}")

    if recursive:
        pdf_files = sorted(folder.rglob("*.pdf"))
    else:
        pdf_files = sorted(folder.glob("*.pdf"))

    if not pdf_files:
        print(f"PDF 파일이 없습니다: {folder_path}")
        return []

    all_docs = []

    for pdf_file in pdf_files:
        try:
            docs = load_pdf(str(pdf_file))
            all_docs.extend(docs)

        except Exception as e:
            print(f"PDF 로드 실패: {pdf_file}")
            print(f"오류 내용: {e}")

    print("=" * 60)
    print(f"전체 PDF 파일 수: {len(pdf_files)}개")
    print(f"전체 Document 수: {len(all_docs)}개")
    print("=" * 60)

    return all_docs


# ============================================================
# 테스트
# ============================================================
if __name__ == "__main__":
    PDF_FOLDER = "./docs"

    docs = load_pdfs_from_folder(
        folder_path=PDF_FOLDER,
        recursive=False,
    )

    if docs:
        print("\n첫 번째 Document 미리보기:")
        print(docs[0].page_content[:500])

        print("\n첫 번째 Document metadata:")
        print(docs[0].metadata)
# Out:
# PDF 로드 및 클린징 완료: docs\id__user_001__김민준.pdf (3페이지)
# metadata 추가 완료: member_id=user_001, member_name=김민준
# PDF 로드 및 클린징 완료: docs\id__user_002__이서연.pdf (3페이지)
# metadata 추가 완료: member_id=user_002, member_name=이서연
# PDF 로드 및 클린징 완료: docs\id__user_003__박지훈.pdf (3페이지)
# metadata 추가 완료: member_id=user_003, member_name=박지훈
# PDF 로드 및 클린징 완료: docs\id__user_004__최수빈.pdf (3페이지)
# metadata 추가 완료: member_id=user_004, member_name=최수빈
# PDF 로드 및 클린징 완료: docs\id__user_005__정하늘.pdf (3페이지)
# metadata 추가 완료: member_id=user_005, member_name=정하늘
# PDF 로드 및 클린징 완료: docs\id__user_006__한지민.pdf (3페이지)
# metadata 추가 완료: member_id=user_006, member_name=한지민
# PDF 로드 및 클린징 완료: docs\id__user_007__김도윤.pdf (3페이지)
# metadata 추가 완료: member_id=user_007, member_name=김도윤
# PDF 로드 및 클린징 완료: docs\id__user_008__이민지.pdf (3페이지)
# metadata 추가 완료: member_id=user_008, member_name=이민지
# PDF 로드 및 클린징 완료: docs\id__user_009__오성민.pdf (3페이지)
# metadata 추가 완료: member_id=user_009, member_name=오성민
# PDF 로드 및 클린징 완료: docs\id__user_010__서예진.pdf (3페이지)
# metadata 추가 완료: member_id=user_010, member_name=서예진
# ============================================================
# 전체 PDF 파일 수: 10개
# 전체 Document 수: 30개
# ============================================================
#
# 첫 번째 Document 미리보기:
# # **가상 건강검진 결과지** Virtual Health Check Report - Sample ### **중요 안내: 본 문서는 앱 화면에 표시된 제한된 생체·체성분 데이터를 기반으로 생성한 가상 샘플입니다. 실제 의료기관의 검진이나 의사의 대면 진료를 대체하지 않습니다.** |문서번호|HU-VHC-20260709-0001|작성일|2026.07.09| |---|---|---|---| |성명|김민준|성별/생년월일|남 / 1998.07.22| |추정 연령|27세|작성기관|헬스업 가상 건강관리센터| ## **1. 검사 결과 요약** |검사항목|측정값|단위|가상 판정|해석 메모| |---|---|---|---|---| |심박|70|bpm|정상|안정시 일반 참고범위 60-100 bpm 기준| |혈당|93|mg/dL|정상|공복혈당으로 가정 시 일반 참고범위 70-99 mg/dL 기준| |혈압|116/79|<br>mmHg|<br>정상|<br>수축기 <120 및 이완기 <80 기준| |몸무게|
#
# 첫 번째 Document metadata:
# {'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-09T13:28:42+00:00', 'source': 'docs\\id__user_001__김민준.pdf', 'file_path': 'docs\\id__user_001__김민준.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '가상 건강검진 및 의사진단 처방전', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-07-09T13:28:42+00:00', 'trapped': '', 'modDate': "D:20260709132842+00'00'", 'creationDate': "D:20260709132842+00'00'", 'page': 0, 'source_file': 'id__user_001__김민준.pdf', 'source_path': 'docs\\id__user_001__김민준.pdf', 'member_id': 'user_001', 'member_name': '김민준', 'source_type': 'member_health_document'}

# %%
# !pip install langchain_text_splitters
# Out:
# Collecting langchain_text_splitters
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\healthcare\.venv\lib\site-packages (from langchain_text_splitters) (1.4.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\healthcare\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\healthcare\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\healthcare\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\healthcare\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\healthcare\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\healthcare\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.4.2)
# Requirement already satisfied: idna>=2.8 in c:\healthcare\.venv\lib\site-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.18)
# Requirement already satisfied: certifi in c:\healthcare\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\healthcare\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\healthcare\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\healthcare\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\healthcare\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.7.0)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: langchain_text_splitters
# Successfully installed langchain_text_splitters-1.1.2
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ============================================================
# Chunk 분할 및 메타데이터 보강 함수
# ============================================================
import os
from datetime import datetime
from langchain_text_splitters import RecursiveCharacterTextSplitter

# ============================================================
# 문서 Chunk 분할
# ============================================================
# RAG에서는 PDF 전체를 한 번에 임베딩하지 않고,
# 검색하기 좋은 작은 단위의 문서 조각(chunk)으로 나눈다.
#
# chunk_size    : 하나의 chunk 최대 글자 수
# chunk_overlap : 앞뒤 chunk가 겹치는 글자 수
#                 문맥이 끊기는 것을 줄이기 위해 사용
# ============================================================
def split_chunks(docs: list, chunk_size: int = 800, chunk_overlap: int = 120) -> list:
    """
    Document 목록을 지정된 크기의 chunk로 분할합니다.

    chunk_size: 하나의 chunk 최대 글자 수
    chunk_overlap: 앞뒤 chunk 간 겹치는 글자 수 (문맥 단절 방지)
    """
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", ".", " ", ""],
    )
    chunks = text_splitter.split_documents(docs)
    print(f"Chunk 분할 완료: {len(docs)}페이지 → {len(chunks)}개 chunk")
    return chunks

# ============================================================
# Chunk 메타데이터 보강
# ============================================================
# PDF Loader가 만든 기본 metadata에
# RAG 저장/검색에 필요한 정보를 추가한다.
# ============================================================
def enrich_metadata(chunks: list, file_path: str) -> list:
    """
    Chunk 메타데이터에 파일 정보, chunk 인덱스, 로드 시각을 추가합니다.
    """
    file_name = os.path.basename(file_path)
    loaded_at = datetime.now().isoformat()
    for i, chunk in enumerate(chunks):
        chunk.metadata.update({
            "file_name":   file_name,
            "file_path":   file_path,
            "source_type": "pdf",
            "loader":      "PyMuPDFLoader",
            "chunk_index": i,
            "loaded_at":   loaded_at,
        })
    print(f"메타데이터 보강 완료: {len(chunks)}개 chunk")
    return chunks


# ============================================================
# 테스트
# ============================================================
if __name__ == "__main__":
    config = get_config()

    chunks = split_chunks(docs, chunk_size=config["chunk_size"], chunk_overlap=config["chunk_overlap"])
    chunks = enrich_metadata(chunks, PDF_FOLDER)

    print(f"\n첫 번째 chunk 메타데이터:")
    print(chunks[0].metadata)

    print(f"\n처음 3개 chunk 미리보기:")
    for i, chunk in enumerate(chunks[:3]):
        print("=" * 60)
        print(f"Chunk {i}: {chunk.page_content[:200]}")
# Out:
# Chunk 분할 완료: 30페이지 → 68개 chunk
# 메타데이터 보강 완료: 68개 chunk
#
# 첫 번째 chunk 메타데이터:
# {'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-09T13:28:42+00:00', 'source': 'docs\\id__user_001__김민준.pdf', 'file_path': './docs', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '가상 건강검진 및 의사진단 처방전', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-07-09T13:28:42+00:00', 'trapped': '', 'modDate': "D:20260709132842+00'00'", 'creationDate': "D:20260709132842+00'00'", 'page': 0, 'source_file': 'id__user_001__김민준.pdf', 'source_path': 'docs\\id__user_001__김민준.pdf', 'member_id': 'user_001', 'member_name': '김민준', 'source_type': 'pdf', 'file_name': 'docs', 'loader': 'PyMuPDFLoader', 'chunk_index': 0, 'loaded_at': '2026-07-15T12:01:06.557552'}
#
# 처음 3개 chunk 미리보기:
# ============================================================
# Chunk 0: # **가상 건강검진 결과지** Virtual Health Check Report - Sample ### **중요 안내: 본 문서는 앱 화면에 표시된 제한된 생체·체성분 데이터를 기반으로 생성한 가상 샘플입니다. 실제 의료기관의 검진이나 의사의 대면 진료를 대체하지 않습니다.** |문서번호|HU-VHC-20260709-0001|작성일|2026.07.09|
# ============================================================
# Chunk 1: . 종합**<br>제공된 수치<br>골격근량은<br>없으므로 확|화면에 표시되지 않<br>**판정**<br>만 기준으로는 혈<br>단일 수치보다 3-<br>정 진단은 불가합|**가**<br>아, 체중 72.5 kg과 B<br>압, 혈당, BMI, 안<br>6개월 추세 관찰과<br>니다.|**상 샘**<br>MI 22.9를 이용하면<br>정시 심박은 대체<b
# ============================================================
# Chunk 2: # **가상 의사진단 및 소견서** Doctor Opinion Sample - Not for clinical use |문서번호|HU-VHC-20260709-0001|작성일|2026.07.09| |---|---|---|---| |성명|김민준|성별/생년월일|남 / 1998.07.22| |추정 연령|27세|작성기관|헬스업 가상 건강관리센터| ## **1. 가상

# %%
# ============================================================
# Embedding 모델 함수
# ============================================================
# bge-m3 모델을 사용해 문서 chunk를 벡터로 변환한다.
# bge-m3는 일반적으로 1024차원 벡터를 생성한다.
# ============================================================
from langchain_ollama import OllamaEmbeddings


def create_embedding_model(embed_model: str, ollama_base_url: str):
    """Ollama 임베딩 모델 인스턴스를 생성하여 반환합니다."""
    embeddings = OllamaEmbeddings(
        model=embed_model,
        base_url=ollama_base_url,
    )
    print(f"임베딩 모델 준비 완료: {embed_model}")
    return embeddings


# ============================================================
# Chunk를 임베딩하여 rag_documents 테이블에 저장 함수
# ============================================================
# 처리 흐름:
# 1. chunk 내용 추출
# 2. Ollama bge-m3로 embedding 생성
# 3. vector 차원 검증
# 4. PostgreSQL rag_documents 테이블에 저장
# ============================================================
import json
from sqlalchemy import text as sql_text

# ============================================================
# INSERT SQL
# ============================================================
# SQLAlchemy에서는 %s 대신 :파라미터명 형식을 사용한다.
# pgvector 컬럼에는 문자열을 CAST(:embedding AS vector) 형태로 변환해서 넣는다.
# metadata는 CAST(:metadata AS jsonb) 형태로 변환해서 넣는다.
# ============================================================
_INSERT_SQL = sql_text("""
    INSERT INTO rag_documents (
        source, source_type, page_no, chunk_index,
        content, metadata, embedding
    )
    VALUES (
        :source, :source_type, :page_no, :chunk_index,
        :content, CAST(:metadata AS jsonb), CAST(:embedding AS vector)
    )
""")


def save_chunks_to_db(
    engine,
    chunks: list,
    clear_existing: bool = False,
) -> int:
    """
    Chunk 목록을 임베딩하여 rag_documents 테이블에 저장합니다.

    Returns:
        int: 저장된 chunk 수
    """
    saved_count = 0

    #임베딩 모델 객체 생성
    config = get_config()
    embeddings = create_embedding_model(config["embed_model"], config["ollama_base_url"])

    with engine.begin() as conn:
        if clear_existing:
            conn.execute(sql_text("DELETE FROM rag_documents;"))
            print("기존 데이터 삭제 완료")

        for idx, chunk in enumerate(chunks):
            content  = chunk.page_content
            metadata = chunk.metadata or {}

            source       = metadata.get("source")
            source_type  = metadata.get("source_type", "pdf")
            page_no      = metadata.get("page")
            chunk_index  = metadata.get("chunk_index")

            #chunk 내용을 백터로 임베딩
            vector = embeddings.embed_query(content)

            if len(vector) != config["embedding_dim"]:
                raise ValueError(
                    f"임베딩 차원 불일치: expected={config['embedding_dim']}, actual={len(vector)}"
                )

            vector_text = "[" + ",".join(map(str, vector)) + "]"

            conn.execute(_INSERT_SQL, {
                "source":      source,
                "source_type": source_type,
                "page_no":     page_no,
                "chunk_index": chunk_index,
                "content":     content,
                "metadata":    json.dumps(metadata, ensure_ascii=False),
                "embedding":   vector_text,
            })

            saved_count += 1
            if saved_count % 10 == 0:
                print(f"{saved_count}개 저장 완료")

    print(f"전체 저장 완료: {saved_count}개 chunk")
    return saved_count


# ============================================================
# 테스트
# ============================================================
if __name__ == "__main__":
    config = get_config()
    
    saved = save_chunks_to_db(
        engine=engine,
        chunks=chunks,
        clear_existing=True,
    )
    print(f"\n저장된 chunk 수: {saved}")
# Out:
# 임베딩 모델 준비 완료: bge-m3
# 기존 데이터 삭제 완료
# 10개 저장 완료
# 20개 저장 완료
# 30개 저장 완료
# 40개 저장 완료
# 50개 저장 완료
# 60개 저장 완료
# 전체 저장 완료: 68개 chunk
#
# 저장된 chunk 수: 68
